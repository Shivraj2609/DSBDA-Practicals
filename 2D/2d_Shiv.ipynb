# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Loading Data Set

# %%
df = pd.read_csv('airquality.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day humidity
# 0           1   41.0    190.0   7.4    67      5    1     high
# 1           2   36.0    118.0   8.0    72      5    2     high
# 2           3   12.0    149.0  12.6    74      5    3     high
# 3           4   18.0    313.0  11.5    62      5    4     high
# 4           5    NaN      NaN  14.3    56      5    5     high

# %%
df["Ozone"] = df["Ozone"].fillna(37)
df["Solar.R"] = df["Solar.R"].fillna(137)
df.drop('Unnamed: 0',inplace=True,axis = 1)

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day humidity
# 0     41.0    190.0   7.4    67      5    1     high
# 1     36.0    118.0   8.0    72      5    2     high
# 2     12.0    149.0  12.6    74      5    3     high
# 3     18.0    313.0  11.5    62      5    4     high
# 4     37.0    137.0  14.3    56      5    5     high
# ..     ...      ...   ...   ...    ...  ...      ...
# 148   30.0    193.0   6.9    70      9   26     high
# 149   37.0    145.0  13.2    77      9   27     high
# 150   14.0    191.0  14.3    75      9   28     high
# 151   18.0    131.0   8.0    76      9   29     high
# 152   20.0    223.0  11.5    68      9   30     high
#
# [153 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# humidity    4
# dtype: int64

# %%
p = df['Month'].value_counts()

# %%
mean_of_cols = [df['Solar.R'].mean(),df['Ozone'].mean(),df['Temp'].mean(),df['Wind'].mean()]

# %% [markdown]
# ## Plot Pie Chart

# %%
plt.pie([df["Ozone"].mean(),df["Solar.R"].mean(),df["Wind"].mean(),df["Temp"].mean()], autopct="%1.2f%%", explode=[0.01,0.01,0.01,0.01], labels=["Ozone", "Solar.R", "Wind", "Temp"])
plt.plot()
# Out:
# []

# %% [markdown]
# ## Plot the Bar

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day humidity
# 0   41.0    190.0   7.4    67      5    1     high
# 1   36.0    118.0   8.0    72      5    2     high
# 2   12.0    149.0  12.6    74      5    3     high
# 3   18.0    313.0  11.5    62      5    4     high
# 4   37.0    137.0  14.3    56      5    5     high

# %% [markdown]
# ## Bar Plot

# %%
plt.title('Month Wise Temperature')
sns.barplot(data = df,x='Month',y ='Temp')
# Out:
# <AxesSubplot:title={'center':'Month Wise Temperature'}, xlabel='Month', ylabel='Temp'>

# %% [markdown]
# ## Plot The Box

# %%
plt.title('Box Plot for Temp vs Month')
sns.boxenplot(data=df,x = 'Month',y = 'Temp')
# Out:
# <AxesSubplot:title={'center':'Box Plot for Temp vs Month'}, xlabel='Month', ylabel='Temp'>

# %% [markdown]
# ## Visualize Line Graph

# %%
plt.title('Temperature vs Ozone')
sns.lineplot(data=df,x='Ozone',y='Temp')
# Out:
# <AxesSubplot:title={'center':'Temperature vs Ozone'}, xlabel='Ozone', ylabel='Temp'>

# %% [markdown]
# ## Visualize The Scatterplot

# %%
plt.title('Scatterplot showing that Solar.R with Temp')
sns.scatterplot(data=df,x='Temp',y='Solar.R',hue='Temp',markers=3)
# Out:
# <AxesSubplot:title={'center':'Scatterplot showing that Solar.R with Temp'}, xlabel='Temp', ylabel='Solar.R'>

# %% [markdown]
# ## Visualize the PairPlot

# %%
sns.pairplot(data=df)

# %% [markdown]
# ## Visualize the Heatmap

# %%
plt.title('Heatmap')
sns.heatmap(df.corr(),linecolor='white',linewidths=2,annot=True)
# Out:
# <AxesSubplot:title={'center':'Heatmap'}>

# %% [markdown]
# ## Visualize the Histogram

# %%
plt.title('Histogram')
sns.histplot(data=df,x='Temp',bins=30,hue='Month')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, xlabel='Temp', ylabel='Count'>

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

text = """ Vision is the Power that sustains it may ne , an importantn aspect of the life where the subjects are boring and not to study well while exam coming """

wordclod = WordCloud(width=1000,height=1000,
                    background_color='white',
                    stopwords = stopwords,
                    min_font_size = 10).generate(text)

plt.imshow(wordclod)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
